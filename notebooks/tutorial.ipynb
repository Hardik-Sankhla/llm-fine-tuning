# %% [markdown]
# # LLM Fine-Tuning Tutorial
#
# This notebook demonstrates how to use the LLM Fine-Tuning Toolkit to fine-tune a language model.

# %%
# Install dependencies (if not already installed)
# !pip install -e ..

import sys
sys.path.append('..')

from main import main
import argparse

# %% [markdown]
# ## Basic Fine-Tuning
#
# Let's fine-tune a small model on a simple dataset.

# %%
# Simulate command line arguments
args = argparse.Namespace(
    model_name='microsoft/DialoGPT-small',
    dataset_name='wikitext',
    output_dir='./output',
    num_epochs=1,  # Reduce for demo
    max_length=256,  # Reduce for demo
    use_peft=True
)

# Run fine-tuning
main(
    model_name=args.model_name,
    dataset_name=args.dataset_name,
    output_dir=args.output_dir,
    num_epochs=args.num_epochs,
    max_length=args.max_length,
    use_peft=args.use_peft,
)

# %% [markdown]
# ## Evaluation
#
# Now let's evaluate the fine-tuned model.

# %%
from evaluate import generate_text

# Load model and tokenizer (assuming training completed)
# model, tokenizer = load_model_and_tokenizer('./output')

# Generate some text
# prompt = "The future of AI is"
# generated = generate_text(model, tokenizer, prompt, max_length=50)
# print(generated[0])
